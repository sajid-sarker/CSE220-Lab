# %%
class Node:
  def __init__(self,val=None,next=None):
    self.elem=val
    self.next=next


def linkedList(arr):

  for idx in range(len(arr)):
    val = arr[idx]
    if idx==0:
      head = Node(val,None)
      tail=head
    else:
      node = Node(val,None)
      tail.next=node
      tail=node
  return head

def printList(head):
  n=head
  while(n!=None):
    if n.next !=None:
      print(n.elem,end='-->')
    else:
      print(n.elem)
    n=n.next

## TO DO ##
class Stack:

  def __init__(self):
    self.top=None

  def push(self,val):
    pass

  def pop(self):
    pass

  def isEmpty(self):
    pass

  # This function is supposed to return a "head" Node that points to the
  # reversed linked list
  # Hint : Will need to use push() and pop() method
  def reverseList(self,head):
    pass

# %%
arr=[12,0,1,5,7,2,3,8]
head =  linkedList(arr)
print("xxxxxx1xxxxxx")
printList(head)
print("xxxxxx2xxxxxx")
stack = Stack()
head = stack.reverseList(head)
printList(head)
print("xxxxxx3xxxxxx")
